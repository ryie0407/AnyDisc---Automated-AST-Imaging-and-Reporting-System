# %%
# !python detect.py \
--input_folder /home/ubuntu/02.WGS/AnyDisc-Public_1105/Test_data/ATCC25922_ATRI \
--output_folder /home/ubuntu/02.WGS/AnyDisc-Public_1105/Test_data/ATCC25922_ATRI/output_results
# Out:
# Processing image: ATCC25922_ATRI_2.jpg
# Model loaded successfully
# Model input image shape: (3, 544, 640)
# Original image shape: (480, 570, 3)
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Scaled detection coordinates:
# x1: 390.0, y1: 262.0, x2: 426.0, y2: 299.0
# x1: 302.0, y1: 143.0, x2: 340.0, y2: 181.0
# x1: 220.0, y1: 300.0, x2: 256.0, y2: 336.0
# Marked the CF30 with higher confidence as CT10 to correct the missing CT10 situation
# Dish width (dish_pix): 427
# Align inhibition zone 1 with antibiotic CT10 concentric
# Align inhibition zone 2 with antibiotic ER5 concentric
# Align inhibition zone 3 with antibiotic CF30 concentric
# ...

# %%
# 測試圖片
# !python detect.py \
--input_folder /home/ubuntu/02.WGS/AnyDisc-Public/data/TestPhoto \
--output_folder /home/ubuntu/02.WGS/AnyDisc-Public/data/TestPhoto/output_results
# Out:
# 處理圖像: 2024-03-07_11:44:13.jpg
# 模型成功載入
# /home/ubuntu/miniconda3/lib/python3.10/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 完成信心分配，成功檢測到所需的三種類別：CF30, CT10, ER5
# Dish width (dish_pix): 444
# 校準抑菌圈 1 與抗生素 ER5 同心
# 校準抑菌圈 2 與抗生素 CF30 同心
# 校準抑菌圈 3 與抗生素 CT10 同心
# /home/ubuntu/02.WGS/AnyDisc-Public/MIC5.py:416: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CD_list_no_dish['MIC_name'] = Mname
# /home/ubuntu/02.WGS/AnyDisc-Public/MIC5.py:417: SettingWithCopyWarning:
# ...
